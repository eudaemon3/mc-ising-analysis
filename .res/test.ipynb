# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(['notebook', 'science'])

from lib.ising_model import IsingModel, _metropolis_open
from lib.lattice_2d import Lattice2D

# %%
N = 50
spin_prob = 0.75
steps = 1_000_000
a_time = np.arange(steps-1) 
beta_j = 0.7
lattice = Lattice2D(N, spin_prob)
lattice._show_img()

# %%
fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(10,4))
ax1.plot(a_time, spins/N**2)
ax1.set_xlabel(r'Time Steps $t$', fontsize=18)
ax1.set_ylabel(r'Average Spin $\bar{m}$', fontsize=18)
ax1.grid()
ax2.plot(a_time, energies)
ax2.set_xlabel(r'Time Steps $t$', fontsize=18)
ax2.set_ylabel(r'Energy $E/J$', fontsize=18)
ax2.grid()
fig.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.plot(1/beta_j, ms_n, 'o--', label=r'75% of spins started negative')
plt.plot(1/beta_j, ms_p, 'o--', label=r'75% of spins started positive')
plt.xlabel(r'$\left(\frac{k}{J}\right)T$')
plt.ylabel(r'$\bar{m}$')
plt.legend(facecolor='white', framealpha=1)
plt.show()
